# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Checking the pandas version

# %%
#Pandas version

pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# # Importing the dataset

# %%
#Importing the dataset
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv
# Out:
# --2024-09-25 14:58:45--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 298573 (292K) [text/plain]
# Saving to: ‘laptops.csv’
#
# laptops.csv         100%[===================>] 291.58K  --.-KB/s    in 0.03s
#
# 2024-09-25 14:58:45 (8.20 MB/s) - ‘laptops.csv’ saved [298573/298573]

# %%
laptops_df=pd.read_csv('laptops.csv')
laptops_df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# ...

# %% [markdown]
# # Counting the total number of records in the dataset

# %%
laptops_df.index+=1

# %%
laptops_df
# Out:
#                                                  Laptop       Status   Brand  \
# 1     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 2     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 3     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 4     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 5     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2159  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2160  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
#Records count

laptops_df.index.size
# Out:
# 2160

# %%
len(laptops_df)
# Out:
# 2160

# %%
laptops_df.shape[0]
# Out:
# 2160

# %% [markdown]
# # Laptop brands

# %%
laptops_df
# Out:
#                                                  Laptop       Status   Brand  \
# 1     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 2     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 3     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 4     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 5     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2159  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2160  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
laptops_df.Brand.nunique()
# Out:
# 27

# %% [markdown]
# # Calculating the total number of columns with missing values in the dataset

# %%
laptops_df.isnull().sum() #returns a Series
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
missing_values = laptops_df.isnull().sum()
total=0
# Print names of columns with missing values
for column, count in missing_values.items():
    if count > 0:
      total+=1
      print(f"Column '{column}' has {count} missing values.")
print('\n')
print(f"Hence '{total}' columns with missing values are present in the given dataset ")
# Out:
# Column 'Storage type' has 42 missing values.
# Column 'GPU' has 1371 missing values.
# Column 'Screen' has 4 missing values.
#
#
# Hence '3' columns with missing values are present in the given dataset

# %% [markdown]
# # Maximum Final Price
#
#
# ```
# What's the maximum final price of Dell notebooks in the dataset?
# ```

# %%
laptops_df.tail()
# Out:
#                                                  Laptop       Status  Brand  \
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2158  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2159  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished  Razer
# 2160  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished  Razer
#
#       Model                CPU  RAM  Storage Storage type       GPU  Screen  \
# 2156  Blade      Intel Core i7   16     1000          SSD  RTX 3060    17.3
# 2157  Blade      Intel Core i7   16     1000          SSD  RTX 3070    17.3
# 2158  Blade      Intel Core i7   32     1000          SSD  RTX 3080    17.3
# 2159   Book  Intel Evo Core i7   16     1000          SSD       NaN    13.4
# 2160   Book  Intel Evo Core i7   16      256          SSD       NaN    13.4
#
#      Touch  Final Price
# 2156    No      2699.99
# ...

# %%
laptops_df[laptops_df['Brand']=="Dell"]["Final Price"].max()
# Out:
# 3936.0

# %% [markdown]
# # Median Value Of Screen

# %%
laptops_df.head()
# Out:
#                                               Laptop Status   Brand  \
# 1  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 2  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 3  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 4  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 5  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 1  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 2          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 3  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 4      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 5         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 1    No      1009.00
# 2    No       299.00
# 3    No       789.00
# ...

# %%
#Find the median value of Screen column in the dataset.

laptops_df['Screen'].median()
# Out:
# 15.6

# %%
#Calculate the most frequent value of the same Screen column.

laptops_df['Screen'].mode()
# Out:
# 0    15.6
# Name: Screen, dtype: float64

# %%
#Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.

laptops_df['Screen'].isnull().sum()
# Out:
# 4

# %%
laptops_df["Screen"]=laptops_df["Screen"].fillna(laptops_df['Screen'].mode()[0])

#Since mode() can return multiple values, using [0] accesses the first mode in the Series.

# %%
laptops_df['Screen'].isnull().sum()
# Out:
# 0

# %%
laptops_df['Screen'].median()
# Out:
# 15.6

# %% [markdown]
# # Sum Of Weights

# %%
laptops_df.columns.tolist()
# Out:
# ['Laptop',
#  'Status',
#  'Brand',
#  'Model',
#  'CPU',
#  'RAM',
#  'Storage',
#  'Storage type',
#  'GPU',
#  'Screen',
#  'Touch',
#  'Final Price']

# %%
laptops_df.columns.nunique()
# Out:
# 12

# %%
# Select all the "Innjoo" laptops from the dataset && Select only columns RAM, Storage, Screen

X=laptops_df[laptops_df['Brand']=="Innjoo"][['RAM', 'Storage', 'Screen']]

# %%
X=X.values #Convert to numpy array from data frame , we could even use X.to_numpy()

# %%
X
# Out:
# array([[  8. , 256. ,  15.6],
#        [  8. , 512. ,  15.6],
#        [  4. ,  64. ,  14.1],
#        [  6. ,  64. ,  14.1],
#        [  6. , 128. ,  14.1],
#        [  6. , 128. ,  14.1]])

# %%
#Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX

XTX=X.T.dot(X)

# %%
#Compute the inverse of XTX
XTX_inv=np.linalg.inv(XTX)

# %%
y=np.array([[1100, 1300, 800, 900, 1000, 1100]])

# %%
#Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w

w=XTX_inv.dot(X.T).dot(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-7f0a0455c9c3> in <cell line: 3>()
#       1 #Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w
#       2
# ----> 3 w=XTX_inv.dot(X.T).dot(y)
#
# ValueError: shapes (3,6) and (1,6) not aligned: 6 (dim 1) != 1 (dim 0)

# %%
XTX
# Out:
# array([[2.52000e+02, 8.32000e+03, 5.59800e+02],
#        [8.32000e+03, 3.68640e+05, 1.73952e+04],
#        [5.59800e+02, 1.73952e+04, 1.28196e+03]])

# %%
XTX.shape
# Out:
# (3, 3)

# %%
XTX_inv.shape
# Out:
# (3, 3)

# %%
(X.T).shape
# Out:
# (3, 6)

# %%
X.T
# Out:
# array([[  8. ,   8. ,   4. ,   6. ,   6. ,   6. ],
#        [256. , 512. ,  64. ,  64. , 128. , 128. ],
#        [ 15.6,  15.6,  14.1,  14.1,  14.1,  14.1]])

# %%
y.shape
# Out:
# (1, 6)

# %%
#MATRIX MULTIPLICATION n*m = a*b where m==b

# %%
#Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w

w=XTX_inv.dot(X.T).dot(y.T)

# %%
#Sum of all elements in the result w

w.sum()
# Out:
# 91.2998806299555
